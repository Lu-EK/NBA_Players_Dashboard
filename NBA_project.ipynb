# %%
import pandas as pd
import matplotlib as mp
import duckdb

# %%
from nba_api.stats.endpoints import leagueleaders
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.static import players
from nba_api.stats.endpoints import leaguedashplayerstats
from nba_api.stats.endpoints import boxscoreadvancedv2

# %%
# Essayons de recuperer les statistiques avanceees d'un joueur sur les dernieres annees

# %%
#AD normal split

career = playercareerstats.PlayerCareerStats(player_id="203076")
df = career.get_data_frames()[0]
df
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203076   2012-13        00  1610612740               NOH        20.0
# 1      203076   2013-14        00  1610612740               NOP        21.0
# 2      203076   2014-15        00  1610612740               NOP        22.0
# 3      203076   2015-16        00  1610612740               NOP        23.0
# 4      203076   2016-17        00  1610612740               NOP        24.0
# 5      203076   2017-18        00  1610612740               NOP        25.0
# 6      203076   2018-19        00  1610612740               NOP        26.0
# 7      203076   2019-20        00  1610612747               LAL        27.0
# 8      203076   2020-21        00  1610612747               LAL        28.0
# 9      203076   2021-22        00  1610612747               LAL        29.0
# 10     203076   2022-23        00  1610612747               LAL        30.0
# ...

# %%
#AD advanced split
AD = leaguedashplayerstats.LeagueDashPlayerStats(80, measure_type_detailed_defense='Advanced')
df = AD.get_data_frames()[0]
df
# Out:
#      PLAYER_ID      PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  \
# 0      1630639      A.J. Lawson     A.J.  1610612742               DAL  23.0
# 1      1631260         AJ Green       AJ  1610612749               MIL  24.0
# 2      1631100       AJ Griffin       AJ  1610612737               ATL  20.0
# 3       203932     Aaron Gordon    Aaron  1610612743               DEN  28.0
# 4      1628988    Aaron Holiday    Aaron  1610612745               HOU  27.0
# ..         ...              ...      ...         ...               ...   ...
# 530    1628380     Zach Collins     Zach  1610612759               SAS  26.0
# 531     203897      Zach LaVine     Zach  1610612741               CHI  28.0
# 532    1630192       Zeke Nnaji     Zeke  1610612743               DEN  23.0
# 533    1630533  Ziaire Williams   Ziaire  1610612763               MEM  22.0
# 534    1629627  Zion Williamson     Zion  1610612740               NOP  23.0
#
# ...

# %%
column_names = df.columns.tolist()
print("Column Names:", column_names)
# Out:
# Column Names: ['PLAYER_ID', 'SEASON_ID', 'LEAGUE_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']

# %%
## 1st task : find how to create/import a full table with advanced statistics for a Single Player "Luka Doncic"
